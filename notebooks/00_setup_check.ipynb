# %% [markdown]
# # Setup check
#
# Run this notebook after installing the environment to confirm all core dependencies
# are importable and report their versions.

# %%
import pandas as pd
import numpy as np
import matplotlib
import sklearn

print(f"pandas      {pd.__version__}")
print(f"numpy       {np.__version__}")
print(f"matplotlib  {matplotlib.__version__}")
print(f"scikit-learn {sklearn.__version__}")

# %%
print("HyCAN-DB environment OK")
